# %% [markdown]
# Corona Trujillo Jesus Enrique - 20390689

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Leer Datos

# %%
df=pd.read_csv('df_arabica_clean.csv')
df
# Out:
#      Unnamed: 0   ID Country of Origin                             Farm Name  \
# 0             0    0          Colombia                      Finca El Paraiso
# 1             1    1            Taiwan              Royal Bean Geisha Estate
# 2             2    2              Laos                    OKLAO coffee farms
# 3             3    3        Costa Rica                             La Cumbre
# 4             4    4          Colombia                       Finca Santuario
# ..          ...  ...               ...                                   ...
# 202         202  202            Brazil                     Fazenda Conquista
# 203         203  203         Nicaragua                      Finca San Felipe
# 204         204  204              Laos                                     -
# 205         205  205       El Salvador  Rosario de Maria II, Area de La Pila
# 206         206  206            Brazil                         Walter Matter
#
# ...

# %% [markdown]
# Number of rows and columns

# %%
num_rows = df.shape[0]
num_columns = df.shape[1]
print("Número de filas:", num_rows)
print("Número de columnas:", num_columns)
# Out:
# Número de filas: 207
# Número de columnas: 41

# %% [markdown]
# Number of categorical variables and number of unique values for each

# %%
categorical_vars = df.select_dtypes(include='object').columns
num_unique_values = df[categorical_vars].nunique()
print("Número de variables categóricas:", len(categorical_vars))
print("Número de valores únicos para cada variable categórica:")
print(num_unique_values)
# Out:
# Número de variables categóricas: 22
# Número de valores únicos para cada variable categórica:
# Country of Origin         22
# Farm Name                172
# Lot Number               187
# Mill                     162
# ICO Number                67
# Company                   72
# Altitude                  97
# Region                   120
# Producer                 172
# Bag Weight                39
# In-Country Partner        21
# Harvest Year               7
# Grading Date              75
# Owner                     80
# Variety                   48
# Status                     1
# Processing Method         10
# Color                     12
# Expiration                75
# Certification Body        21
# Certification Address     21
# Certification Contact     21
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Obtener las variables categóricas del DataFrame
categorical_vars = df.select_dtypes(include='object').columns

# Calcular el número de valores únicos para cada variable categórica
num_unique_values = df[categorical_vars].nunique()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
num_unique_values.plot(kind='bar')
plt.title("Número de valores únicos para cada variable categórica")
plt.xlabel("Variables categóricas")
plt.ylabel("Número de valores únicos")
plt.xticks(rotation=45)
plt.show()

# %%
#Missing_values
missing_values = df.isnull().sum()
print("Valores faltantes por columna:")
print(missing_values)
# Out:
# Valores faltantes por columna:
# Unnamed: 0                 0
# ID                         0
# Country of Origin          0
# Farm Name                  2
# Lot Number                 1
# Mill                       3
# ICO Number               132
# Company                    0
# Altitude                   1
# Region                     2
# Producer                   1
# Number of Bags             0
# Bag Weight                 0
# In-Country Partner         0
# Harvest Year               0
# Grading Date               0
# Owner                      0
# Variety                    6
# Status                     0
# Processing Method          5
# Aroma                      0
# Flavor                     0
# Aftertaste                 0
# Acidity                    0
# Body                       0
# Balance                    0
# Uniformity                 0
# Clean Cup                  0
# Sweetness                  0
# Overall                    0
# Defects                    0
# ...

# %%
attribute_stats = df.describe(include='all')
print("Estadísticas resumidas para atributos:")
print(attribute_stats)
# Out:
# Estadísticas resumidas para atributos:
#         Unnamed: 0          ID Country of Origin  \
# count   207.000000  207.000000               207
# unique         NaN         NaN                22
# top            NaN         NaN            Taiwan
# freq           NaN         NaN                61
# mean    103.000000  103.000000               NaN
# std      59.899917   59.899917               NaN
# min       0.000000    0.000000               NaN
# 25%      51.500000   51.500000               NaN
# 50%     103.000000  103.000000               NaN
# 75%     154.500000  154.500000               NaN
# max     206.000000  206.000000               NaN
#
#                            Farm Name Lot Number      Mill ICO Number  \
# count                            205        206       204         75
# unique                           172        187       162         67
# top     Doi Tung Development Project          1  Dry Mill        non
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Cargar el conjunto de datos
df = pd.read_csv("df_arabica_clean.csv")

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y_actual, test_size=0.2, random_state=42)
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Realizar predicciones en los datos de prueba
y_pred = modelo.predict(X_test)

# Calcular el error cuadrático medio (MSE) y el error absoluto medio (MAE)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Error cuadrático medio (MSE):", mse)
print("Error absoluto medio (MAE):", mae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 10
#       7 df = pd.read_csv("df_arabica_clean.csv")
#       9 # Dividir los datos en conjuntos de entrenamiento y prueba
# ---> 10 X_train, X_test, y_train, y_test = train_test_split(X, y_actual, test_size=0.2, random_state=42)
#      11 modelo = LinearRegression()
#      12 modelo.fit(X_train, y_train)
#
# NameError: name 'X' is not defined

# %%
import pandas as pd
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Cargar el archivo CSV en un DataFrame de pandas
data = pd.read_csv('df_arabica_clean.csv')

# Definir las columnas de características y la variable objetivo
features = ['Altitude', 'Total Cup Points', 'Moisture Percentage', 'Category One Defects', 'Quakers']
target = 'Color'

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(data[features], data[target], test_size=0.2, random_state=42)

# LassoCV sin normalización
lasso_cv = LassoCV(cv=5)
lasso_cv.fit(X_train, y_train)
score_without_normalization = lasso_cv.score(X_test, y_test)

# LassoCV con normalización de datos
scaler = StandardScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

lasso_cv_normalized = LassoCV(cv=5)
lasso_cv_normalized.fit(X_train_normalized, y_train)
score_with_normalization = lasso_cv_normalized.score(X_test_normalized, y_test)

# Imprimir los puntajes
print("Puntuación sin normalización:", score_without_normalization)
print("Puntuación con normalización:", score_with_normalization)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 18
#      16 # LassoCV sin normalización
#      17 lasso_cv = LassoCV(cv=5)
# ---> 18 lasso_cv.fit(X_train, y_train)
#      19 score_without_normalization = lasso_cv.score(X_test, y_test)
#      21 # LassoCV con normalización de datos
#
# File c:\programs\reccoonvir\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1556, in LinearModelCV.fit(self, X, y, sample_weight)
#    1545 else:
#    1546     # Need to validate separately here.
#    1547     # We can't pass multi_output=True because that would allow y to be
#    1548     # csr. We also want to allow y to be 64 or 32 but check_X_y only
#    1549     # allows to convert for 64.
#    1550     check_X_params = dict(
#    1551         accept_sparse="csc",
#    1552         dtype=[np.float64, np.float32],
#    1553         order="F",
# ...
